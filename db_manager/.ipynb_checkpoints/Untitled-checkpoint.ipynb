# %%
import sqlite3 as sq
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
con = sq.connect('../CP.db')

# %%
status_lu = pd.read_sql('SELECT * FROM instruments_lu WHERE(shortname="status")', con)
status_tables = list(status_lu.instr_table)
status_lu
# Out:
#   shortname instr_model site  height  rep  instr_sn  logger_sn  \
# 0    status      CR3000   NF     0.0    1      9809       9809
# 1    status     CR1000X   NF     0.0    2     23311      23311
# 2    status      CR3000   NF     0.0    3     10365      10365
# 3    status      CR1000   NF     0.0    4      3863       3863
# 4    status      CR1000   NF     0.0    5      3860       3860
# 5    status      CR1000   NF     0.0    6      3864       3864
#
#        instr_table                  comment
# 0  status_NF_0cm_1         NF EC 17m logger
# 1  status_NF_0cm_2      NF Burba 17m logger
# 2  status_NF_0cm_3          NF EC 3m logger
# 3  status_NF_0cm_4           NF3 sap logger
# 4  status_NF_0cm_5  first snow logger at NF
# 5  status_NF_0cm_6          NF soils logger

# %%
fig = plt.figure()

table_name = status_lu.instr_table[0]
ax = fig.add_subplot(2,1,1)
print(table_name)
status1 = pd.read_sql(f'SELECT * FROM {table_name} WHERE(stat="avg")', con, parse_dates=['timestamp']).replace(['NAN'], [np.nan]).sort_values('timestamp')
duplicate_ts1 = status1[status1.duplicated(subset=['timestamp'], keep=False)]
status1.plot('timestamp', 'vlogger_1_1_1', kind='scatter', s=0.5, figsize=(20, 5), ax = ax)
duplicate_ts1.plot('timestamp', 'vlogger_1_1_1', kind='scatter', color='red', ax=ax, s=1)

table_name = status_lu.instr_table[2]
ax = fig.add_subplot(2,1,2)
print(table_name)
status2 = pd.read_sql(f'SELECT * FROM {table_name} WHERE(stat="avg")', con, parse_dates=['timestamp']).replace(['NAN'], [np.nan]).sort_values('timestamp')
duplicate_ts2 = status2[status2.duplicated(subset=['timestamp'], keep=False)]
display(duplicate_ts2)
status2.plot('timestamp', 'vlogger_2_1_1', kind='scatter', s=0.5, figsize=(20, 5), ax = ax)
duplicate_ts2.plot('timestamp', 'vlogger_2_1_1', kind='scatter', color='red', ax=ax, s=1)
# Out:
# status_NF_0cm_1
# status_NF_0cm_3
#        idx           timestamp stat  vlogger_2_1_1  tlogger_2_1_1
# 4455  4455 2019-07-11 07:30:00  avg       12.22873       14.12567
# 4462  4462 2019-07-11 07:30:00  avg       12.22873       14.12567
# 4456  4456 2019-07-11 08:00:00  avg       12.26542       15.64531
# 4463  4463 2019-07-11 08:00:00  avg       12.26542       15.64531
# 4464  4464 2019-07-11 08:30:00  avg       12.42678       17.06113
# 4457  4457 2019-07-11 08:30:00  avg       12.42678       17.06113
# 4458  4458 2019-07-11 09:00:00  avg       12.62776       18.47753
# 4465  4465 2019-07-11 09:00:00  avg       12.62776       18.47753
# 4459  4459 2019-07-11 09:30:00  avg       12.66888       19.78731
# 4466  4466 2019-07-11 09:30:00  avg       12.66888       19.78731
# 4460  4460 2019-07-11 10:00:00  avg       12.67154       20.96604
# 4467  4467 2019-07-11 10:00:00  avg       12.67154       20.96604
# 4461  4461 2019-07-11 10:30:00  avg       12.82720       22.28062
# 4468  4468 2019-07-11 10:30:00  avg       12.82720       22.28062
# <AxesSubplot:xlabel='timestamp', ylabel='vlogger_2_1_1'>

# %%
ec3_status = status2.set_index('timestamp')
ec17_status = status1.set_index('timestamp')

# %%
time_array = pd.DataFrame(pd.date_range('2019-01-01 00:00:00', '2022-03-01 00:00:00', freq='30 min'), columns=['timestamp']).set_index('timestamp').sort_values('timestamp')

# %%
ec_status = ec3_status.join(ec17_status, on=['timestamp'], lsuffix='2_1_1', rsuffix='1_1_1', how='inner')
ec_status = ec_status.join(time_array, how='right').sort_values('timestamp')

# %%
ec_status
# Out:
#                      idx2_1_1 stat2_1_1  vlogger_2_1_1  tlogger_2_1_1  \
# timestamp
# 2019-01-01 00:00:00       NaN       NaN            NaN            NaN
# 2019-01-01 00:30:00       NaN       NaN            NaN            NaN
# 2019-01-01 01:00:00       NaN       NaN            NaN            NaN
# 2019-01-01 01:30:00       NaN       NaN            NaN            NaN
# 2019-01-01 02:00:00       NaN       NaN            NaN            NaN
# ...                       ...       ...            ...            ...
# 2022-02-28 22:00:00   50525.0       avg       12.07359      -1.851012
# 2022-02-28 22:30:00   50526.0       avg       12.06489      -2.185365
# 2022-02-28 23:00:00   50527.0       avg       12.05772      -2.397401
# 2022-02-28 23:30:00   50528.0       avg       12.05148      -2.412764
# 2022-03-01 00:00:00   50529.0       avg       12.04553      -2.293280
#
#                      idx1_1_1 stat1_1_1  vlogger_1_1_1  tlogger_1_1_1
# timestamp
# 2019-01-01 00:00:00       NaN       NaN            NaN            NaN
# 2019-01-01 00:30:00       NaN       NaN            NaN            NaN
# 2019-01-01 01:00:00       NaN       NaN            NaN            NaN
# 2019-01-01 01:30:00       NaN       NaN            NaN            NaN
# 2019-01-01 02:00:00       NaN       NaN            NaN            NaN
# ...                       ...       ...            ...            ...
# 2022-02-28 22:00:00   44661.0       avg            NaN      18.497590
# 2022-02-28 22:30:00   44662.0       avg       15.88050      17.113060
# 2022-02-28 23:00:00   44663.0       avg       14.90384      12.403940
# 2022-02-28 23:30:00   44664.0       avg       16.84298      21.209860
# 2022-03-01 00:00:00   44665.0       avg       14.15286       9.045943
#
# [59579 rows x 8 columns]

# %%
# find indices for nans without repeats
nans = np.array(sorted(list(set(list(np.where(np.isnan(ec_status[['tlogger_1_1_1']]))[0]) + list(np.where(np.isnan(ec_status[['tlogger_2_1_1']]))[0])))))
# find gaps between nans
gapsizes = np.diff(nans)
# where gaps are greater than one, there is a continuous run of data
where_nan_runs_end = np.where(gapsizes - 1)
# find the length of this run
data_length = gapsizes[where_nan_runs_end] - 1
# start of this run of data and where it ends
data_start = nans[where_nan_runs_end] + 1
next_nan = data_start + data_length 

data_start, next_nan
# Out:
# (array([ 5472,  5514,  5519,  5990, 11789, 16752, 16802, 16848, 16944,
#         17470, 17498, 17518, 17558, 17616, 17762, 18144, 18240, 29497,
#         29828, 30898, 30911, 33430, 35035, 45190, 45384, 48008, 57303,
#         58169, 58447, 59350, 59398, 59400, 59447, 59543]),
#  array([ 5494,  5518,  5969, 10797, 16745, 16793, 16841, 16889, 17397,
#         17491, 17513, 17551, 17575, 17705, 18080, 18185, 29069, 29511,
#         29954, 30901, 32289, 34693, 45180, 45374, 46314, 56193, 58163,
#         58315, 59241, 59357, 59399, 59404, 59451, 59545]))

# %%
len(data_start)
# Out:
# 34

# %%
for start, end in zip(data_start[1:5], next_nan[1:5]):
    out = signal.correlate(ec_status.tlogger_1_1_1[start:end].values, ec_status.tlogger_2_1_1[start:end].values, mode='full')
#     print(out)
    plt.plot(ec_status.tlogger_1_1_1[start:end])

# %%
def standardize(x):
    return (x - x.mean())/x.std()

# %%
fig = plt.figure(figsize=(25,100))
fig.suptitle('Time Lag Relative to EC3 logger', y=0.89, fontsize=30)
plt.tight_layout()
i=0
for start, end in zip(data_start, next_nan):
    if end - start > 48*4:
        print(ec_status[start:end].reset_index().duplicated(subset=['timestamp']).sum())
        fig.add_subplot(36,2,i+1)
        size = len(ec_status.tlogger_1_1_1[start:end])
        t = np.arange(0, size, 1)/2  # hours
        plt.plot(ec_status.tlogger_1_1_1[start:end], label='EC17')
        plt.plot(ec_status.tlogger_2_1_1[start:end], label='EC3')
        plt.xticks(rotation=45)
        plt.ylabel('Logger Temperature')
        if i==0: plt.legend()

        lags = signal.correlation_lags(size, size)/2
        corr = signal.correlate(standardize(ec_status.tlogger_2_1_1[start:end]), standardize(ec_status.tlogger_1_1_1[start:end]))
        fig.add_subplot(36,2,i+2)
        plt.plot(lags, corr/size, lw=2)
        plt.ylabel('Correlation')
        plt.xlabel('Time behind EC3 Logger, hours')
       
        lag = lags[np.argmax(corr)]
        plt.vlines(lag, -10, 10, lw=2, linestyle='--', color='k')
        plt.text(lag + 2, -0.5, lag, fontsize=20)
        plt.ylim(-1.2, 1.2)
        plt.xlim(-36, 36)    
        i += 4
# Out:
# 4
# 7
# 0
# 0
# 0
# 1888
# 0
# 0
# 2
# 0
# 2153
# 0
# 0

# %%
from scipy import signal
from numpy.random import default_rng
rng = default_rng()
x = rng.standard_normal(1000)
y = np.concatenate([rng.standard_normal(100), x])
correlation = signal.correlate(x, y, mode="full")
lags = signal.correlation_lags(x.size, y.size, mode="full")
lag = lags[np.argmax(correlation)]
lag
# Out:
# -100

# %%
ec_status.iloc[5250:5300]
# Out:
#                      idx2_1_1 stat2_1_1  vlogger_2_1_1  tlogger_2_1_1  \
# timestamp
# 2019-08-12 17:00:00      6017       avg       12.60858      20.916570
# 2019-08-12 17:30:00      6018       avg       12.54078      20.621690
# 2019-08-12 18:00:00      6019       avg       12.50740      20.163040
# 2019-08-12 18:30:00      6020       avg       12.47395      19.568660
# 2019-08-12 19:00:00      6021       avg       12.45106      18.881800
# 2019-08-12 19:30:00      6022       avg       12.43079      17.974750
